# %%
import matplotlib.pyplot as plt
import numpy as np

# 空白图像
plt.figure()
#直线
x = [1,2,3,4,5,6,7,8]
y = [2,3,4,5,6,7,8,9]
y_sin = np.sin(x)
plt.plot(x, y, color='r', linewidth=2.0, linestyle='--')

#散点图
xs = np.random.randint(0,10,50)
ys = np.random.randint(0,10,50)
plt.scatter(xs, ys, color='b', marker='o')

#柱状图
plt.figure()
xb = ['A','B','C','D','E']
yb = [10, 20,30, 40, 50]
plt.bar(xb, yb, color='g')

#画饼
plt.figure()
ap = [15, 30, 45, 10]
explodep = [0.1, 0.1, 0.1, 0.1]
litp = 'Frogs', 'Hogs', 'Dogs', 'Logs'
colp = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
plt.pie(ap, explode=explodep, labels=litp, colors=colp)
plt.axis()

#直方图
plt.figure()
N = np.random.normal(0, 1, size=99999)
plt.hist(N, bins=999, alpha=1, color='m')

#箱线图
plt.figure()
data = [np.random.normal(0, 1, 1000)]
plt.boxplot(data, vert=False, sym='o')

#热力图
plt.figure()
xim = [[1100,278,80],[2, 98, 239],[87, 1223, 9]]
plt.imshow(xim, cmap='hot', interpolation='nearest')
plt.colorbar()

#创建一个2行2列子图网格
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,y)

plt.subplot(2,2,2)
plt.hist(N, bins=999, alpha=0.5, color='red')

plt.subplot(2,2,3)
plt.scatter(xs, ys, color='r', marker='x')

plt.subplot(2,2,4)
plt.bar(xb, yb, color='g')

#返回子图的对象和轴对象
#创建figure(8,6) dpi=80
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(x, y, color='r')
plt.plot(x, 10*y_sin, color='black')

#title添加标题
plt.title('Line', fontweight='heavy', color='b')

#xlabel & ylabel
plt.xlabel('random_x', color='b')
plt.ylabel('random_y', color='b')

#添加横轴纵轴刻度
#A = [1,2,3,4,5]
#plt.xticks(A)
#plt.yticks(A)
#如果plt.xticks([]),则表示不显示刻度

#legend
plt.legend(['Random', 'Sine'], loc='upper left')

#网格
#plt.grid(axis='y', color='b') #plt.grid(True, color=' ') False关闭网格

#text文本信息
plt.text(1,-10,'what fuck?', ha='left')

#添加箭头注释
plt.annotate('Min_value', xy=(5, -9.5), xytext=(6, -9), color='r', arrowprops=dict(arrowstyle='->'))

#保存图片
plt.savefig('name.png', dpi=80, )

#

plt.show()
